# %%
# import scipy;
import numpy as np
import pandas as pd
# import sklearn;
# print("Scipy %s" % scipy.__version__);
# print("Numpy %s" % numpy.__version__);
# print("Pandas %s" % pandas.__version__);
# print("SkLearn %s" % sklearn.__version__)

# %%
df = pd.read_csv('./simulated_data.csv')
df
# Out:
#              id   absrate1    nsusp1  mobility1    q1mpa1    q2mpa1    q3mpa1  \
# 0         Abbie   8.691872 -0.241215   1.316117  2.007210  2.013601  2.328796
# 1          Abby   2.679866 -0.429858   0.988551  2.610177  2.035795  2.925415
# 2       Abigail   2.390263 -0.000734   1.582128  1.944150  2.372956  2.747949
# 3           Ada   1.104282  0.256327   0.463057  3.802947  3.620091  3.022131
# 4          Adah  -0.321349 -0.651360   0.943529  3.847125  3.358561  3.363801
# 5       Adaline  -1.362514 -0.067581   1.010893  3.659162  4.231653  3.792451
# 6          Adda   9.141146  0.298396   1.513853  2.675233  1.945841  2.361056
# 7         Addie   0.626882  0.274565  -0.098882  3.552760  4.032728  3.892030
# 8         Adela   8.656492 -0.017992   0.333171  3.348454  3.802583  3.581944
# 9      Adelaide   1.137438 -0.056874  -0.449919  4.972929  4.177104  4.176310
# 10        Adele   5.306100 -0.091351  -0.581559  4.397947  4.652861  4.271944
# ...

# %%
df.iloc[0] # Can access through index
# Out:
# id              Abbie
# absrate1      8.69187
# nsusp1      -0.241215
# mobility1     1.31612
# q1mpa1        2.00721
# q2mpa1         2.0136
# q3mpa1         2.3288
# q4mpa1        2.50631
# absrate2      4.44592
# nsusp2      -0.013065
# mobility2     1.09659
# q1mpa2        2.92884
# q2mpa2        2.17571
# q3mpa2        2.10289
# q4mpa2        1.96352
# absrate3      7.89012
# nsusp3       0.214621
# mobility3    0.867511
# q1mpa3         2.2346
# q2mpa3        2.53615
# q3mpa3        2.41992
# q4mpa3        1.46546
# absrate4      7.09375
# nsusp4       0.452587
# mobility4     1.06568
# q1mpa4        2.21968
# q2mpa4        1.16958
# q3mpa4        1.28493
# q4mpa4       0.936805
# absrate5      9.40668
# nsusp5       0.391348
# mobility5     1.14887
# q1mpa5        1.74438
# q2mpa5        1.09966
# q3mpa5        1.15757
# q4mpa5        1.97728
# absrate6      12.8257
# nsusp6       0.469379
# mobility6     1.40791
# q1mpa6        2.29762
# q2mpa6         1.1237
# ...

# %%
print df.iloc[0][0] # Can access through index
print df.iloc[0].id # Can access through column names (label)
# TODO: Pandas DF can be created from numpy array too. Look into it when needed
# Out:
# Abbie
# Abbie

# %%
df.id
# Out:
# 0           Abbie
# 1            Abby
# 2         Abigail
# 3             Ada
# 4            Adah
# 5         Adaline
# 6            Adda
# 7           Addie
# 8           Adela
# 9        Adelaide
# 10          Adele
# 11         Adelia
# 12        Adeline
# 13          Adell
# 14         Adella
# 15         Agatha
# 16          Aggie
# 17          Agnes
# 18           Aida
# 19          Aimee
# 20           Alba
# 21         Albert
# 22        Alberta
# 23      Albertine
# 24         Albina
# 25           Alda
# 26         Aletha
# 27         Alfred
# 28        Alfreda
# 29          Alice
#           ...
# 970    Wilhelmina
# 971    Wilhelmine
# 972          Will
# 973          Rene
# 974         Willa
# 975       William
# 976        Seward
# 977        Willie
# 978       Shannon
# 979         Wilma
# 980      Winifred
# 981        Winnie
# 982     Winnifred
# 983        Winona
# 984          Zada
# 985         Zadie
# 986         Zaida
# 987         Zella
# 988         Zelma
# ...

# %%
df.iloc[0].count()
# TODO: Check why len( df.iloc[0] ) is not working.
# Out:
# 51

# %%
# Using `iloc[]`
print(df.iloc[0][0])

# Using `loc[]`
print(df.loc[0]['id'])

# Using `at[]`
print(df.at[0,'id'])

# Using `iat[]`
print(df.iat[0,0])

# Using `get_value(index, column)`
print(df.get_value(0, 'id'))
# Out:
# Abbie
# Abbie
# Abbie
# Abbie
# Abbie

# %%
print(df.loc[:, 'id'])
# Out:
# 0           Abbie
# 1            Abby
# 2         Abigail
# 3             Ada
# 4            Adah
# 5         Adaline
# 6            Adda
# 7           Addie
# 8           Adela
# 9        Adelaide
# 10          Adele
# 11         Adelia
# 12        Adeline
# 13          Adell
# 14         Adella
# 15         Agatha
# 16          Aggie
# 17          Agnes
# 18           Aida
# 19          Aimee
# 20           Alba
# 21         Albert
# 22        Alberta
# 23      Albertine
# 24         Albina
# 25           Alda
# 26         Aletha
# 27         Alfred
# 28        Alfreda
# 29          Alice
#           ...
# 970    Wilhelmina
# 971    Wilhelmine
# 972          Will
# 973          Rene
# 974         Willa
# 975       William
# 976        Seward
# 977        Willie
# 978       Shannon
# 979         Wilma
# 980      Winifred
# 981        Winnie
# 982     Winnifred
# 983        Winona
# 984          Zada
# 985         Zadie
# 986         Zaida
# 987         Zella
# 988         Zelma
# ...
